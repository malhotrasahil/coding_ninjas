# %%
import numpy as np
import pandas as pd

terror=pd.read_csv("C:\\Users\\Sahil\\Downloads\\terrorismData.csv")


df=terror.copy()

# %%
df_jk=df[df['State']=='Jammu and Kashmir']
df_jk.shape
df_jk.head()
df_jk=df_jk[df_jk['Group'] !='Unknown']
df_jk.head()
df_jk.shape
df_jk.describe(include ='all')
# Out:
#                Year       Month         Day Country              State  \
# count    983.000000  983.000000  983.000000     983                983
# unique          NaN         NaN         NaN       1                  1
# top             NaN         NaN         NaN   India  Jammu and Kashmir
# freq            NaN         NaN         NaN     983                983
# mean    2002.297050    6.362157   15.442523     NaN                NaN
# std        9.465193    3.102964    8.529958     NaN                NaN
# min     1984.000000    1.000000    0.000000     NaN                NaN
# 25%     1995.000000    4.000000    8.000000     NaN                NaN
# 50%     2001.000000    6.000000   15.000000     NaN                NaN
# 75%     2013.000000    9.000000   23.000000     NaN                NaN
# max     2017.000000   12.000000   31.000000     NaN                NaN
#
#             Region      City    Latitude   Longitude     AttackType  \
# ...

# %%
df_jk_city=df_jk['City']
df_jk_city.describe()
# Out:
# count          983
# unique         277
# top       Srinagar
# freq           351
# Name: City, dtype: object

# %%
city=(df_jk_city.describe()['top'])
freq=(df_jk_city.describe()['freq'])

# %%
df_jk_city_filtered=df_jk[df_jk['City']==city]
df_jk_city_filtered.shape
# Out:
# (351, 17)

# %%
group=df_jk_city_filtered.describe(include='all')['Group'].loc['top']
freq=df_jk_city_filtered.describe(include='all')['Group'].loc['freq']

# %%
print(str(city) +' '+str(int(freq))+ ' '+ group)
# Out:
# Srinagar 55 Muslim Separatists
