# %%
## Open and read data file as specified in the question
## Print the required output in given format
import requests
import json

headers = {'User-Agent':"BhavyaJain", "Accept":"application/vnd.github.hellcat-preview+json",
          'Authorization':'token 0cdf751450bc1e968f42277870accaa9672badc5'}

# params = {"anon": "true"}

response = requests.get('https://api.github.com/repos/CodingNinjasCodes/JSNotes/stats/contributors', headers = headers)
response_json = json.loads(response.text)

# /repos/:owner/:repo/contributors
print(response_json)

# for i in response_json:
#     print(i['login'], i['contributions'])
# Out:
# [{'total': 5, 'weeks': [{'w': 1483228800, 'a': 13, 'd': 0, 'c': 3}, {'w': 1483833600, 'a': 0, 'd': 0, 'c': 0}, {'w': 1484438400, 'a': 1, 'd': 0, 'c': 1}, {'w': 1485043200, 'a': 0, 'd': 0, 'c': 0}, {'w': 1485648000, 'a': 0, 'd': 0, 'c': 0}, {'w': 1486252800, 'a': 0, 'd': 0, 'c': 0}, {'w': 1486857600, 'a': 0, 'd': 0, 'c': 0}, {'w': 1487462400, 'a': 0, 'd': 0, 'c': 0}, {'w': 1488067200, 'a': 0, 'd': 0, 'c': 0}, {'w': 1488672000, 'a': 0, 'd': 0, 'c': 0}, {'w': 1489276800, 'a': 0, 'd': 0, 'c': 0}, {'w': 1489881600, 'a': 0, 'd': 0, 'c': 0}, {'w': 1490486400, 'a': 0, 'd': 0, 'c': 0}, {'w': 1491091200, 'a': 0, 'd': 0, 'c': 0}, {'w': 1491696000, 'a': 0, 'd': 0, 'c': 0}, {'w': 1492300800, 'a': 0, 'd': 0, 'c': 0}, {'w': 1492905600, 'a': 0, 'd': 0, 'c': 0}, {'w': 1493510400, 'a': 0, 'd': 0, 'c': 0}, {'w': 1494115200, 'a': 0, 'd': 0, 'c': 0}, {'w': 1494720000, 'a': 0, 'd': 0, 'c': 0}, {'w': 1495324800, 'a': 0, 'd': 0, 'c': 0}, {'w': 1495929600, 'a': 0, 'd': 0, 'c': 0}, {'w': 1496534400, 'a': 0, '
# ...

# %%
for i in response_json:
    print(i['author']['login'], i['total'])
# Out:
# tushartuteja 5
# Rawal27 13
# Sherawat42 15
