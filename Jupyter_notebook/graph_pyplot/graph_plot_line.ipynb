# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x =[0,1,2,3,4,5,6,7,9,10]
y=[1,2,5,10,17,26,37,50,82,101]
y2=[2,3,15,10,16,76,37,50,80,105]

# %%
plt.plot(x,y,marker='+',color='green',linewidth=1,label="first")
plt.plot(x,y2,label="second")
plt.grid()
plt.legend()
# plt.scatter(x,y,color='purple')
plt.axis([0,15,0,140])
plt.text(2,80,"hello",fontsize=10)
plt.ylabel("ylabel")
plt.xlabel("xlabel")
plt.title("title")
plt.show()
