# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x =[0,1,2,3,4,5,6,7,9,10]
y=[1,2,5,10,17,26,37,50,82,101]

# %%
plt.scatter(x,y)
plt.figure()
plt.plot(x,y,'r-.')
plt.scatter(x,y)
plt.grid()
plt.figure()
# plt.show()
